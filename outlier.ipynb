# %% [markdown]
# <a href="https://colab.research.google.com/github/dhakalsameer/CG-/blob/main/outlier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dataset
data = np.array([50, 55, 52, 48, 51, 60, 62, 54, 53, 47, 65, 90])

print("Dataset:", data)

# Calculate Q1, Q3, IQR
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("\nQ1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Detect outliers
outliers = data[(data < lower_bound) | (data > upper_bound)]

print("\nOutliers:", outliers)

# Boxplot
plt.boxplot(data)
plt.title("Boxplot of Exam Scores")
plt.show()
